# %% [markdown]
# - [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shubhankarreddy/From-Python-to-ML/blob/main/00.Welcome-Demo.ipynb) 00. Welcome Demo

# %% [markdown]
# # Welcome!
#
# You are currently looking at a **Jupyter Notebook** hosted on **Google Colab**.
#
# It is a cloud-based environment that lets you write and run Python code directly in your browser — no installation needed.

# %% [markdown]
# ## How to Use This Notebook
#
# This notebook has two types of **cells**:
#
# 1. **Text cells** — like this one. They contain explanations.
# 2. **Code cells** — they have a grey background. You can write and run Python code in them.
#
# **To run a code cell:**
#
# Click on the cell, then press **Shift + Enter** on your keyboard.
#
# That's it. Try it on the code cells below.

# %% [markdown]
# ## What is Python?
#
# Python is a programming language.
# We use it to give instructions to the computer.
#
# In Data Science, Python helps us:
# - Store data
# - Clean data
# - Analyze data
# - Build models

# %% [markdown]
# ## print() Function
#
# In Python, `print()` is how we tell the computer to show us a result or a message on the screen.

# %%
# Printing a simple message
print("Hello, Learner!")
# Out:
# Hello, Learner!

# %%
# By giving "#" we are telling Python that this is a comment.
# The computer ignores comments.
# We use them to explain what the code does.

# %%
# Python as a calculator

print(20 + 25)
# Out:
# 45

# %%
# Python can do subtraction, multiplication, and division too

print(100 - 30)
print(6 * 7)
print(150 / 3)
# Out:
# 70
# 42
# 50.0

# %% [markdown]
# ### Practice Task
#
# 1. Print your name using `print()`.
# 2. Print your favorite hobby.
# 3. Use `print()` to calculate `250 * 4`.
# 4. Try: what does `10 - 3 * 2` give? Run it and see.

# %%
# Write your answers here:

# %% [markdown]
# ## How to Follow This Course
#
# This course is organized as a series of notebooks, numbered in order:
#
# - **01** → Variables and Data Types
# - **02** → Strings
# - **03** → Lists
# - **04** → Tuples and Sets
# - ... and so on.
#
# Go through them **in order**. Each notebook builds on the previous one.
#
# Every notebook has **practice questions** at the end. Try solving them before moving to the next topic — that's where the real learning happens.
