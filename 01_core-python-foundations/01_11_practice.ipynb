# %% [markdown]
# # 11. Practice — Core Python Foundations
#
# This notebook is a **complete revision** of everything we learned in Module 1.
#
# It covers:
#
# - Variables and Data Types
# - Strings
# - Lists
# - Tuples and Sets
# - Dictionaries
# - Operators
# - Conditional Statements
# - Loops
# - Functions
#
# The questions are arranged in **3 levels**:
#
# 1. **Level 1 — Basics** : One concept at a time. Quick recall.
# 2. **Level 2 — Combine** : Mix two or three concepts together.
# 3. **Level 3 — Mini Projects** : Small real-world problems using everything.
#
# Try solving each question on your own **before** looking at the solution.
#
# ---

# %% [markdown]
# # LEVEL 1 — Basics
#
# One concept per question. Warm-up round.

# %% [markdown]
# ### Q1. Variables and Data Types
#
# Create the following variables:
#
# - `name` → your name (string)
# - `age` → your age (integer)
# - `height` → your height in meters (float)
# - `is_student` → True or False (boolean)
#
# Print each variable and its type using `type()`.

# %%
# Your code here

# %% [markdown]
# ### Q2. Type Conversion
#
# You are given:
#
# ```python
# price = "450"
# quantity = "3"
# ```
#
# 1. Convert both to integers.
# 2. Calculate total cost (price × quantity).
# 3. Print the total and its type.

# %%
# Your code here

# %% [markdown]
# ### Q3. String Operations
#
# You are given:
#
# ```python
# raw = "   dATA scIENCE is FUN   "
# ```
#
# 1. Remove extra spaces.
# 2. Convert to title case.
# 3. Replace "Fun" with "Amazing".
# 4. Split into a list of words.
# 5. Print the result of each step.

# %%
# Your code here

# %% [markdown]
# ### Q4. Lists
#
# Create a list: `fruits = ["apple", "banana", "cherry", "date", "elderberry"]`
#
# 1. Print the first and last item.
# 2. Slice and print the middle 3 items.
# 3. Add `"fig"` at the end.
# 4. Insert `"avocado"` at index 1.
# 5. Remove `"cherry"`.
# 6. Sort the list and print it.

# %%
# Your code here

# %% [markdown]
# ### Q5. Tuples and Sets
#
# 1. Create a tuple `coordinates = (18.5204, 73.8567)`. Try changing the first value. What happens?
#
# 2. You are given:
#
# ```python
# emails = ["a@gmail.com", "b@gmail.com", "a@gmail.com", "c@gmail.com", "b@gmail.com"]
# ```
#
# - Convert to a set to get unique emails.
# - Print the number of unique emails.
# - Add `"d@gmail.com"` to the set.
# - Remove `"a@gmail.com"` from the set.

# %%
# Your code here

# %% [markdown]
# ### Q6. Dictionaries
#
# Create a dictionary for a book:
#
# ```python
# book = {
#     "title": "Atomic Habits",
#     "author": "James Clear",
#     "pages": 320
# }
# ```
#
# 1. Print the title using key access.
# 2. Use `.get()` to access a key `"rating"` that does not exist. Print the result.
# 3. Add a new key `"rating"` with value `4.8`.
# 4. Update `"pages"` to `330`.
# 5. Print all keys, all values, and all items.

# %%
# Your code here

# %% [markdown]
# ### Q7. Operators
#
# Given `a = 27` and `b = 4`, predict the output **first**, then run the code:
#
# 1. `a + b`
# 2. `a // b`
# 3. `a % b`
# 4. `a ** 2`
# 5. `a > b and b < 10`
# 6. `a < 20 or b == 4`
# 7. `not (a == 27)`

# %%
# Your code here

# %% [markdown]
# ### Q8. Conditional Statements
#
# Write a program that takes a variable `temp` (temperature in Celsius) and prints:
#
# - `"Freezing"` if temp <= 0
# - `"Cold"` if temp is between 1 and 15
# - `"Pleasant"` if temp is between 16 and 30
# - `"Hot"` if temp is between 31 and 40
# - `"Extreme Heat"` if temp > 40
#
# Test with: `temp = 28`, `temp = -5`, `temp = 42`

# %%
# Your code here

# %% [markdown]
# ### Q9. Loops
#
# 1. Using a `for` loop, print the multiplication table of 7 (from 7×1 to 7×10).
#
# 2. Using a `while` loop, start from `x = 100` and keep subtracting 15 until `x` becomes less than 10. Print `x` at each step.

# %%
# Your code here

# %% [markdown]
# ### Q10. Functions
#
# 1. Create a function `is_even(num)` that returns `True` if the number is even, `False` otherwise.
#
# 2. Create a function `greeting(name, msg="Good Morning")` that prints `"<msg>, <name>!"`
#     - Call it with just a name.
#     - Call it with a name and `"Happy Birthday"`.
#
# 3. Write a lambda that takes a string and returns it reversed.
#     - Test with `"python"`.

# %%
# Your code here

# %% [markdown]
# ---
#
# # LEVEL 2 — Combine
#
# Each question mixes 2–3 concepts. This is where real understanding is tested.

# %% [markdown]
# ### Q11. Loop + List + Conditional
#
# You are given a list of marks:
#
# ```python
# marks = [82, 45, 91, 33, 67, 78, 55, 29, 88, 40]
# ```
#
# Using a loop:
#
# 1. Create two new lists: `passed` (marks >= 40) and `failed` (marks < 40).
# 2. Print both lists.
# 3. Print how many students passed and how many failed.

# %%
# Your code here

# %% [markdown]
# ### Q12. String + Loop + Dictionary
#
# You are given a sentence:
#
# ```python
# sentence = "python is easy and python is powerful"
# ```
#
# 1. Split the sentence into a list of words.
# 2. Using a loop, count how many times each word appears.
# 3. Store the result in a dictionary.
# 4. Print the dictionary.
#
# Expected output: `{'python': 2, 'is': 2, 'easy': 1, 'and': 1, 'powerful': 1}`

# %%
# Your code here

# %% [markdown]
# ### Q13. Function + List + Loop
#
# Create a function `remove_duplicates(items)` that:
#
# 1. Takes a list as input.
# 2. Returns a new list with duplicates removed.
# 3. The order of first appearance should be maintained.
#
# **Do not use `set()`.** Use a loop and an `if` check.
#
# Test with: `["pen", "book", "pen", "eraser", "book", "pen"]`
#
# Expected output: `["pen", "book", "eraser"]`

# %%
# Your code here

# %% [markdown]
# ### Q14. Dictionary + Conditional + Loop
#
# You are given student data:
#
# ```python
# students = {
#     "Amit": 85,
#     "Neha": 42,
#     "Ravi": 73,
#     "Priya": 91,
#     "Suresh": 36
# }
# ```
#
# 1. Loop through the dictionary.
# 2. For each student, print their name and grade:
#     - marks >= 90 → "Grade A"
#     - marks >= 75 → "Grade B"
#     - marks >= 60 → "Grade C"
#     - marks >= 40 → "Grade D"
#     - below 40 → "Fail"
# 3. Also count how many students got each grade.

# %%
# Your code here

# %% [markdown]
# ### Q15. Function + String + Conditional
#
# Create a function `password_checker(password)` that checks:
#
# 1. Length is at least 8 characters.
# 2. Contains at least one digit (0–9).
#
# If both conditions are met, return `"Strong"`.
# If only length is fine but no digit, return `"Weak — add a number"`.
# If length is too short, return `"Too short"`.
#
# Test with: `"hello"`, `"helloworld"`, `"hello123"`
#
# Hint: To check if a string contains a digit, loop through each character and use `char.isdigit()`.

# %%
# Your code here

# %% [markdown]
# ### Q16. Loop + Set + List
#
# You are given two lists representing students who attended two workshops:
#
# ```python
# workshop_a = ["Amit", "Neha", "Ravi", "Priya", "Suresh"]
# workshop_b = ["Neha", "Kavya", "Ravi", "Mohan", "Priya"]
# ```
#
# Using sets, find:
#
# 1. Students who attended **both** workshops.
# 2. Students who attended **at least one** workshop.
# 3. Students who attended **only workshop A** (not B).
# 4. Students who attended **only one** of the two (not both).
#
# Hint: Look up set operations — `&` (intersection), `|` (union), `-` (difference), `^` (symmetric difference).

# %%
# Your code here

# %% [markdown]
# ### Q17. Function + *args + Operators
#
# Create a function `stats(*args)` that takes any number of numbers and returns a dictionary with:
#
# - `"count"` → how many numbers
# - `"total"` → sum of all numbers
# - `"average"` → average (total / count)
# - `"minimum"` → smallest number
# - `"maximum"` → largest number
#
# Test with: `stats(10, 20, 30, 40, 50)` and `stats(3, 7, 1)`

# %%
# Your code here

# %% [markdown]
# ### Q18. Nested Loop + String
#
# Print the following pattern using nested loops:
#
# ```
# *
# **
# ***
# ****
# *****
# ```
#
# Then print the reverse pattern:
#
# ```
# *****
# ****
# ***
# **
# *
# ```

# %%
# Your code here

# %% [markdown]
# ---
#
# # LEVEL 3 — Mini Projects
#
# These are small real-world problems. They combine almost everything from this module.
#
# Take your time. Think about the structure before writing code.

# %% [markdown]
# ### Q19. Student Report Card Generator
#
# You are given:
#
# ```python
# students = [
#     {"name": "Amit", "marks": [78, 82, 90, 65, 70]},
#     {"name": "Neha", "marks": [92, 88, 95, 80, 85]},
#     {"name": "Ravi", "marks": [30, 45, 50, 35, 40]},
#     {"name": "Priya", "marks": [60, 58, 72, 68, 55]},
#     {"name": "Suresh", "marks": [20, 35, 28, 40, 15]}
# ]
# ```
#
# Create the following functions:
#
# 1. `get_average(marks)` → returns the average of a marks list.
#
# 2. `get_grade(average)` → returns the grade string:
#     - >= 90 → "A"
#     - >= 75 → "B"
#     - >= 60 → "C"
#     - >= 40 → "D"
#     - below 40 → "Fail"
#
# 3. `generate_report(students)` → loops through the students list and for each student:
#     - Calculates the average (using `get_average`)
#     - Gets the grade (using `get_grade`)
#     - Prints a line like: `"Amit | Average: 77.0 | Grade: B"`
#     - At the end, prints the class topper (highest average).

# %%
# Your code here

# %% [markdown]
# ### Q20. Shopping Cart
#
# Build a simple shopping cart system using functions and dictionaries.
#
# You are given a product catalog:
#
# ```python
# catalog = {
#     "laptop": 50000,
#     "phone": 15000,
#     "headphones": 2000,
#     "mouse": 500,
#     "keyboard": 1500
# }
# ```
#
# Create:
#
# 1. A function `add_to_cart(cart, item, catalog)` that:
#     - Checks if the item exists in catalog.
#     - If yes, adds it to the cart (a list) and returns `True`.
#     - If not, prints `"Item not available"` and returns `False`.
#
# 2. A function `calculate_total(cart, catalog)` that:
#     - Loops through the cart.
#     - Calculates total price.
#     - Returns total.
#
# 3. A function `apply_discount(total, discount_percent=10)` that:
#     - Applies the discount and returns the final amount.
#
# 4. Use all three functions:
#     - Add "laptop", "mouse", "headphones", and "tablet" (does not exist) to the cart.
#     - Calculate the total.
#     - Apply a 15% discount.
#     - Print the cart, total before discount, and total after discount.

# %%
# Your code here

# %% [markdown]
# ### Q21. Contact Book
#
# Build a simple contact book using functions, dictionaries, and loops.
#
# Create:
#
# 1. An empty dictionary called `contacts`.
#
# 2. A function `add_contact(contacts, name, phone, city="Unknown")` that:
#     - Adds a contact to the dictionary.
#     - Each contact should be stored as: `contacts[name] = {"phone": phone, "city": city}`
#
# 3. A function `search_contact(contacts, name)` that:
#     - Uses `.get()` to safely search.
#     - If found, prints the phone and city.
#     - If not found, prints `"Contact not found"`.
#
# 4. A function `list_all_contacts(contacts)` that:
#     - Loops through and prints every contact's name, phone, and city.
#
# 5. A function `contacts_from_city(contacts, city)` that:
#     - Returns a list of names who live in a given city.
#
# Test:
# - Add at least 4 contacts (at least 2 from the same city).
# - Search for an existing and a non-existing contact.
# - List all contacts.
# - Find all contacts from a specific city.

# %%
# Your code here

# %% [markdown]
# ### Q22. Data Cleaner
#
# You are given messy data from a survey:
#
# ```python
# raw_data = [
#     {"name": "  AMIT sharma ", "age": "25", "city": "pune"},
#     {"name": "neha PATEL  ", "age": "30", "city": "  MUMBAI"},
#     {"name": " ravi KUMAR", "age": "twenty", "city": "delhi  "},
#     {"name": "PRIYA gupta  ", "age": "22", "city": "  pune "},
#     {"name": "  suresh  ", "age": "abc", "city": "mumbai"},
# ]
# ```
#
# Create a function `clean_data(raw_data)` that:
#
# 1. For each record:
#     - Cleans the name: strip spaces, convert to title case.
#     - Cleans the city: strip spaces, convert to title case.
#     - Converts age to integer. If conversion fails (not a valid number), set age to `None`.
#
# 2. Returns a new list of cleaned dictionaries.
#
# 3. After cleaning, loop through the cleaned data and print each record.
#
# 4. Also print how many records had invalid ages.
#
# Hint: Use `try` and `except` to handle age conversion safely:
# ```python
# try:
#     age = int(value)
# except ValueError:
#     age = None
# ```

# %%
# Your code here

# %% [markdown]
# ### Q23. Mini Analytics Engine
#
# You have sales data for a small shop:
#
# ```python
# sales = [
#     {"product": "Pen", "quantity": 100, "price_per_unit": 10},
#     {"product": "Notebook", "quantity": 50, "price_per_unit": 40},
#     {"product": "Eraser", "quantity": 200, "price_per_unit": 5},
#     {"product": "Pencil", "quantity": 150, "price_per_unit": 8},
#     {"product": "Sharpener", "quantity": 80, "price_per_unit": 6},
#     {"product": "Ruler", "quantity": 60, "price_per_unit": 15},
#     {"product": "Glue", "quantity": 40, "price_per_unit": 30},
# ]
# ```
#
# Create:
#
# 1. A function `revenue(item)` that calculates the revenue for a single item (quantity × price).
#
# 2. A function `total_revenue(sales)` that calculates total revenue across all items.
#
# 3. A function `top_product(sales)` that returns the product name with the highest revenue.
#
# 4. A function `above_threshold(sales, min_revenue)` that returns a list of product names whose revenue is above the given threshold.
#
# 5. A function `sales_report(sales)` that prints a full report:
#     - Each product with its revenue.
#     - The total revenue.
#     - The top-selling product.
#     - All products with revenue above 1000.
#
# Call `sales_report(sales)` and see the full output.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## You Made It!
#
# If you solved all 23 questions, you have a solid grip on Core Python.
#
# Quick self-check:
#
# - Can you create and use variables of different types?
# - Can you clean and manipulate strings?
# - Can you work with lists, tuples, sets, and dictionaries?
# - Can you use operators to compare and combine values?
# - Can you write if-elif-else conditions?
# - Can you write for and while loops with break and continue?
# - Can you create functions with parameters, defaults, returns, *args, **kwargs?
# - Can you combine all of the above to solve a real problem?
#
# If yes — you are ready for the next module.
#
# If some topics feel shaky, go back to that specific notebook and revise. That is completely normal and a good use of your time.
